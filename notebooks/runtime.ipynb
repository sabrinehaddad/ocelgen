# %% [markdown]
# # Plot - Runtime

# %%
import sys
import os

# Add project root to sys.path
project_root = os.path.abspath("..")
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# %%
from runtime_experiments.experiments_summary import plot_runtime_summary
plot_runtime_summary(csv_dir="../csv_files", plot_dir="../plots")
# Out:
# /Users/sabrinehaddad/Desktop/ocelgen/runtime_experiments/experiments_summary.py:55: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(
# /Users/sabrinehaddad/Desktop/ocelgen/runtime_experiments/experiments_summary.py:55: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(
# /Users/sabrinehaddad/Desktop/ocelgen/runtime_experiments/experiments_summary.py:55: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(
# /Users/sabrinehaddad/Desktop/ocelgen/runtime_experiments/experiments_summary.py:55: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(
# /Users/sabrinehaddad/Desktop/ocelgen/runtime_experiments/experiments_summary.py:55: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar='sd'` for the same effect.
#
#   sns.lineplot(
# ...
