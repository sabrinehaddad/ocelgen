# %% [markdown]
# # Plot - Representativeness

# %%
# %matplotlib inline

# %%
import sys
import os

# Get absolute path to the project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))
if project_root not in sys.path:
    sys.path.insert(0, project_root)

# Step 2: Now you can import your plotter module
from representativeness_experiments.plotter import run_all_plots

# %%
run_all_plots("../data/real-world_logs", "../data/generated_logs")
# Out:
# [STEP 1] Loading features from real and synthetic logs...
# SUCCESSFULLY: 3 features for BPIC15_Municipality1. Took 0:00:00.243030.
# SUCCESSFULLY: 3 features for p2p. Took 0:00:00.399920.
# SUCCESSFULLY: 3 features for windows_events. Took 0:00:00.478268.
# SUCCESSFULLY: 3 features for o2c. Took 0:00:00.641546.
# SUCCESSFULLY: 3 features for transfer_order. Took 0:00:00.030643.
# SUCCESSFULLY: 3 features for running-example. Took 0:00:00.137392.
# SUCCESSFULLY: 3 features for github_pm4py. Took 0:00:00.004718.
# SUCCESSFULLY: 3 features for recruiting. Took 0:00:00.015051.
# SUCCESSFULLY: 3 features for BPIC15_Municipality2. Took 0:00:00.179234.
# SUCCESSFULLY: 3 features for BPIC15_Municipality5. Took 0:00:00.290584.
# SUCCESSFULLY: 3 features for BPIC15_Municipality4. Took 0:00:00.196681.
# SUCCESSFULLY: 3 features for log_025. Took 0:00:00.000611.
# SUCCESSFULLY: 3 features for log_024. Took 0:00:00.000449.
# SUCCESSFULLY: 3 features for log_113. Took 0:00:00.001676.
# ...
